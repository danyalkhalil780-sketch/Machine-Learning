# %% [markdown]
# ### NAME: MUHAMMAD DANYAL KHALIL
# ### REG NO: 22JZELE0473
# ### UNIVERSITY: UET PESHAWAR (NOWSHERA CAMPUS)
# ### DEPARTMENT: ELECTRICAL (POWER)
# # Lab 10: MLP for Time-Series Forecasting
#
# **Course:** Machine Learning Lab
# **Topic:** Multilayer Perceptron model for AEP time-series prediction
#
# ## Lab Objective
# The objective of this lab is to build and train an MLP model for time-series forecasting. The notebook prepares sequential input data, trains the model, evaluates forecasting error, and performs fine-tuning from a saved checkpoint.

# %% [markdown]
# ## 1. Set Working Directory
# The working directory is changed so the notebook can access the local dataset, helper modules, saved checkpoints, and output files.

# %%
import os
os.chdir(r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\Code')

# %% [markdown]
# ## 2. Import Libraries and Helper Functions
# This cell imports regression metrics, time-series splitting utilities, plotting tools, callbacks, TensorFlow/Keras layers, and preprocessing objects required for forecasting.

# %%
import timeseires
from timeseires.utils.to_split import to_split

# %% [markdown]
# ## 3. Define Initial Parameters
# The model variable, starting epoch, time steps, and number of input features are initialized before building the neural network.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from timeseires.utils.to_split import to_split
from timeseires.utils.multivariate_multi_step import multivariate_multi_step
from timeseires.utils.multivariate_single_step import multivariate_single_step
from timeseires.utils.univariate_multi_step import univariate_multi_step
from timeseires.utils.univariate_single_step import univariate_single_step
from timeseires.utils.CosineAnnealingLRS import CosineAnnealingLRS
from timeseires.callbacks.EpochCheckpoint import EpochCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
from timeseires.callbacks.TrainingMonitor import TrainingMonitor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import LSTM, Bidirectional, Add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv1D,TimeDistributed
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten,MaxPooling1D,Concatenate,AveragePooling1D, GlobalMaxPooling1D, Input
from tensorflow.keras.models import Sequential,Model
import pandas as pd
import time, pickle
import numpy as np
import tensorflow.keras.backend as K
import tensorflow
from tensorflow.keras.layers import Input, Reshape, Lambda
from tensorflow.keras.layers import Layer, Flatten, LeakyReLU, concatenate, Dense
from tensorflow.keras.regularizers import l2
import glob
import h5py
import matplotlib.pyplot as plt
from keras.callbacks import Callback

# %% [markdown]
# ## 4. Define the MLP Architecture
# The MLP flattens the time-step input, passes it through a dense hidden layer, and produces one forecast value. This architecture treats the prepared time window as a fixed-size feature vector.

# %%
#lookback = 24
model = None
start_epoch = 0
time_steps=24
num_features=21

# %% [markdown]
# ## 5. Display Model Summary and Diagram
# The model summary and diagram help verify the input shape, layer structure, and number of trainable parameters.

# %%
def MLP():
    model = Sequential()
    model.add(Flatten(input_shape=(time_steps , num_features)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    return model

# %%
model1 = MLP()
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 504)               0
#
#  dense (Dense)               (None, 32)                16160
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 16,193
# Trainable params: 16,193
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6. Set Output Paths
# The checkpoint, figure, and JSON paths define where the best model and training history will be saved.

# %%
tensorflow.keras.utils.plot_model(model1 )
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
checkpoints = r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
OUTPUT_PATH = r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10'
FIG_PATH = os.path.sep.join([OUTPUT_PATH,"\history.png"])
JSON_PATH = os.path.sep.join([OUTPUT_PATH,"\history.json"])

# %% [markdown]
# ## 7. Configure Training Callbacks
# The checkpoint callback saves the best validation-loss model, while the training monitor stores loss history for later analysis.

# %%
os.path.exists(JSON_PATH)
# Out:
# True

# %% [markdown]
# ## 8. Compile or Load the Model
# If no checkpoint is supplied, a new MLP is compiled using Adam optimizer and MAE loss. Otherwise, training can resume from an existing saved model.

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
#TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,]

# %% [markdown]
# ## 9. Load Train, Validation, and Test Data
# The CSV files are loaded into arrays for sequence preparation. The scaler is also loaded so predictions can later be converted back to original units.

# %%
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model =MLP()
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] compiling model...

# %% [markdown]
# ## 10. Confirm MLP Function and Sequence Examples
# These cells define the MLP again and test the sequence-generation function with different target lengths to understand the input-output format.

# %%
import os
path_dataset =r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\Code'
path_tr = os.path.join(path_dataset, 'train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'AEP_scaler.pkl')
scaler        = pickle.load(open(path_scaler,'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# c:\Users\Lenovo\anaconda3\envs\ml_env\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.0.2 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ((860, 21), (90, 21), (30, 21))

# %%
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=1)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=1)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=1)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.009994029998779297 sec

# %%
train_X.shape
# Out:
# (835, 24, 21)

# %%
epochs = 6
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                    verbose = verbose)
# Out:
# Epoch 1/6
# 16/27 [================>.............] - ETA: 0s - loss: 0.5360 - mae: 0.5360 - mape: 360.0918
# Epoch 1: val_loss improved from inf to 0.11392, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0001-loss0.11.h5
# 27/27 [==============================] - 1s 15ms/step - loss: 0.3923 - mae: 0.3923 - mape: 247.6600 - val_loss: 0.1139 - val_mae: 0.1139 - val_mape: 44.9292
# Epoch 2/6
#  1/27 [>.............................] - ETA: 0s - loss: 0.1091 - mae: 0.1091 - mape: 35.4962
# Epoch 2: val_loss improved from 0.11392 to 0.05269, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0002-loss0.05.h5
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0955 - mae: 0.0955 - mape: 47.5834 - val_loss: 0.0527 - val_mae: 0.0527 - val_mape: 17.8374
# Epoch 3/6
#  1/27 [>.............................] - ETA: 0s - loss: 0.0674 - mae: 0.0674 - mape: 41.2371
# Epoch 3: val_loss improved from 0.05269 to 0.05231, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0003-loss0.05.h5
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0637 - mae: 0.0637 - mape: 33.4475 - val_loss: 0.0523 - val_mae: 0.0523 - val_mape: 17.1143
# Epoch 4/6
#  1/27 [>.............................] - ETA: 0s - loss: 0.0470 - mae: 0.0470 - mape: 12.7264
# Epoch 4: val_loss did not improve from 0.05231
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0548 - mae: 0.0548 - mape: 26.6239 - val_loss: 0.0596 - val_mae: 0.0596 - val_mape: 19.4708
# Epoch 5/6
#  1/27 [>.............................] - ETA: 0s - loss: 0.0550 - mae: 0.0550 - mape: 44.7024
# Epoch 5: val_loss did not improve from 0.05231
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0539 - mae: 0.0539 - mape: 27.8219 - val_loss: 0.0684 - val_mae: 0.0684 - val_mape: 22.6537
# Epoch 6/6
# 16/27 [================>.............] - ETA: 0s - loss: 0.0498 - mae: 0.0498 - mape: 27.4759
# Epoch 6: val_loss did not improve from 0.05231
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0475 - mae: 0.0475 - mape: 24.4028 - val_loss: 0.1146 - val_mae: 0.1146 - val_mape: 41.7550

# %% [markdown]
# ## 11. Prepare Time-Series Windows
# The dataset is converted into supervised-learning samples. Each sample uses previous time steps to predict the target value.

# %%
model = load_model(r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0001-loss0.11.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 197ms/step
# Mean Absolute Error (MAE): 1358.07
# Median Absolute Error (MedAE): 1712.11
# Mean Squared Error (MSE): 2313106.58
# Root Mean Squared Error (RMSE): 1520.89
# Mean Absolute Percentage Error (MAPE): 8.62 %
# Median Absolute Percentage Error (MDAPE): 10.96 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)

# %%
checkpoints = r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-{epoch:04d}-loss{val_loss:.2f}.h5'
model=r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0001-loss0.11.h5'
start_epoch= 6

# %% [markdown]
# ## 12. Train the MLP Model
# The model is trained on prepared sequences and validated on a separate validation set. The callbacks save progress and the best checkpoint.

# %%
# construct the callback to save only the *best* model to disk
# based on the validation loss
EpochCheckpoint1 = ModelCheckpoint(checkpoints,
                             monitor="val_loss",
                             save_best_only=True, 
                             verbose=1)
TrainingMonitor1=TrainingMonitor(FIG_PATH, jsonPath=JSON_PATH, startAt=start_epoch)

# construct the set of callbacks
callbacks = [EpochCheckpoint1,TrainingMonitor1]
# if there is no specific model checkpoint supplied, then initialize
# the network and compile the model
if model is None:
    print("[INFO] compiling model...")
    model = PC.build(time_steps=24, num_features=21, reg=0.0005)
    opt = Adam(1e-3)
    model.compile(loss= 'mae', optimizer=opt, metrics=["mae", "mape"])
# otherwise, load the checkpoint from disk
else:
    print("[INFO] loading {}...".format(model))
    model = load_model(model)

    # update the learning rate
    print("[INFO] old learning rate: {}".format(K.get_value(model.optimizer.lr)))
    K.set_value(model.optimizer.lr, 1e-4)
    print("[INFO] new learning rate: {}".format(K.get_value(model.optimizer.lr)))
# Out:
# [INFO] loading H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0001-loss0.11.h5...
# [INFO] old learning rate: 0.0010000000474974513
# [INFO] new learning rate: 9.999999747378752e-05

# %% [markdown]
# ## 13. Evaluate Forecasting Performance
# The saved model predicts the test data. Predictions and true values are inverse-transformed, then MAE, RMSE, MAPE, and R2 are calculated to evaluate performance.

# %%
epochs = 10
verbose = 1 #0
batch_size = 32
History = model.fit(train_X,
                        train_y,
                        batch_size=batch_size,   
                        epochs = epochs, 
                        validation_data = (validation_X,validation_y),
                        callbacks=callbacks,
                        verbose = verbose)
# Out:
# Epoch 1/10
#  1/27 [>.............................] - ETA: 6s - loss: 0.1051 - mae: 0.1051 - mape: 31.3014
# Epoch 1: val_loss improved from inf to 0.07897, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0001-loss0.08.h5
# 27/27 [==============================] - 1s 17ms/step - loss: 0.1054 - mae: 0.1054 - mape: 51.0536 - val_loss: 0.0790 - val_mae: 0.0790 - val_mape: 30.4853
# Epoch 2/10
#  1/27 [>.............................] - ETA: 0s - loss: 0.0834 - mae: 0.0834 - mape: 49.9098
# Epoch 2: val_loss improved from 0.07897 to 0.06762, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0002-loss0.07.h5
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0915 - mae: 0.0915 - mape: 44.5903 - val_loss: 0.0676 - val_mae: 0.0676 - val_mape: 25.5359
# Epoch 3/10
#  1/27 [>.............................] - ETA: 0s - loss: 0.0956 - mae: 0.0956 - mape: 35.0088
# Epoch 3: val_loss improved from 0.06762 to 0.04781, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0003-loss0.05.h5
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0837 - mae: 0.0837 - mape: 42.6233 - val_loss: 0.0478 - val_mae: 0.0478 - val_mape: 18.0057
# Epoch 4/10
#  1/27 [>.............................] - ETA: 0s - loss: 0.0928 - mae: 0.0928 - mape: 35.8346
# Epoch 4: val_loss did not improve from 0.04781
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0789 - mae: 0.0789 - mape: 41.1199 - val_loss: 0.0490 - val_mae: 0.0490 - val_mape: 17.8957
# Epoch 5/10
# 16/27 [================>.............] - ETA: 0s - loss: 0.0722 - mae: 0.0722 - mape: 33.1984
# Epoch 5: val_loss improved from 0.04781 to 0.04624, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0005-loss0.05.h5
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0737 - mae: 0.0737 - mape: 38.1741 - val_loss: 0.0462 - val_mae: 0.0462 - val_mape: 16.9148
# Epoch 6/10
# 19/27 [====================>.........] - ETA: 0s - loss: 0.0684 - mae: 0.0684 - mape: 37.3873
# Epoch 6: val_loss improved from 0.04624 to 0.04619, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0006-loss0.05.h5
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0692 - mae: 0.0692 - mape: 35.7841 - val_loss: 0.0462 - val_mae: 0.0462 - val_mape: 16.3630
# Epoch 7/10
# 17/27 [=================>............] - ETA: 0s - loss: 0.0676 - mae: 0.0676 - mape: 35.2770
# Epoch 7: val_loss improved from 0.04619 to 0.04440, saving model to H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E2-cp-0007-loss0.04.h5
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0664 - mae: 0.0664 - mape: 35.2735 - val_loss: 0.0444 - val_mae: 0.0444 - val_mape: 15.7141
# Epoch 8/10
# 17/27 [=================>............] - ETA: 0s - loss: 0.0632 - mae: 0.0632 - mape: 31.2086
# Epoch 8: val_loss did not improve from 0.04440
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0622 - mae: 0.0622 - mape: 32.4453 - val_loss: 0.0478 - val_mae: 0.0478 - val_mape: 16.8977
# Epoch 9/10
# 16/27 [================>.............] - ETA: 0s - loss: 0.0600 - mae: 0.0600 - mape: 30.8817
# Epoch 9: val_loss did not improve from 0.04440
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0601 - mae: 0.0601 - mape: 32.2263 - val_loss: 0.0479 - val_mae: 0.0479 - val_mape: 16.7073
# Epoch 10/10
# 16/27 [================>.............] - ETA: 0s - loss: 0.0597 - mae: 0.0597 - mape: 32.6558
# Epoch 10: val_loss did not improve from 0.04440
# 27/27 [==============================] - 0s 19ms/step - loss: 0.0563 - mae: 0.0563 - mape: 29.7167 - val_loss: 0.0451 - val_mae: 0.0451 - val_mape: 15.0733

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# ## 14. Fine-Tuning Setup
# Fine-tuning starts from a previous checkpoint and continues training from the selected epoch. This can improve the model if more training is needed.

# %%
model = load_model(r'H:\DRIVE D DATA\UET\8th Semester\Machine Learning Lab\lab no 10\E1-cp-0001-loss0.11.h5')

y_pred_scaled   = model.predict(test_X)
y_pred          = scaler.inverse_transform(y_pred_scaled)
y_test_unscaled = scaler.inverse_transform(test_y)
# Mean Absolute Error (MAE)
MAE = np.mean(abs(y_pred - y_test_unscaled)) 
print('Mean Absolute Error (MAE): ' + str(np.round(MAE, 2)))

# Median Absolute Error (MedAE)
MEDAE = np.median(abs(y_pred - y_test_unscaled))
print('Median Absolute Error (MedAE): ' + str(np.round(MEDAE, 2)))

# Mean Squared Error (MSE)
MSE = np.square(np.subtract(y_pred, y_test_unscaled)).mean()
print('Mean Squared Error (MSE): ' + str(np.round(MSE, 2)))

# Root Mean Squarred Error (RMSE) 
RMSE = np.sqrt(np.mean(np.square(y_pred - y_test_unscaled)))
print('Root Mean Squared Error (RMSE): ' + str(np.round(RMSE, 2)))

# Mean Absolute Percentage Error (MAPE)
MAPE = np.mean((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Mean Absolute Percentage Error (MAPE): ' + str(np.round(MAPE, 2)) + ' %')

# Median Absolute Percentage Error (MDAPE)
MDAPE = np.median((np.abs(np.subtract(y_test_unscaled, y_pred)/ y_test_unscaled))) * 100
print('Median Absolute Percentage Error (MDAPE): ' + str(np.round(MDAPE, 2)) + ' %')

print('\n\ny_test_unscaled.shape= ',y_test_unscaled.shape)
print('y_pred.shape= ',y_pred.shape)
# Out:
# 1/1 [==============================] - 0s 70ms/step
# Mean Absolute Error (MAE): 1358.07
# Median Absolute Error (MedAE): 1712.11
# Mean Squared Error (MSE): 2313106.58
# Root Mean Squared Error (RMSE): 1520.89
# Mean Absolute Percentage Error (MAPE): 8.62 %
# Median Absolute Percentage Error (MDAPE): 10.96 %
#
#
# y_test_unscaled.shape=  (5, 1)
# y_pred.shape=  (5, 1)

# %% [markdown]
# ## 15. Fine-Tuning Callbacks and Model Loading
# The callbacks are rebuilt and the existing model is loaded so training can continue from the saved checkpoint.

# %% [markdown]
# ## 16. Continue Training
# The model is trained for additional epochs using the same training and validation sequences.

# %% [markdown]
# ## 17. Evaluate After Fine-Tuning
# The fine-tuned checkpoint is loaded and tested again using the same evaluation metrics. This allows comparison before and after fine-tuning.

# %% [markdown]
# ## Conclusion
# This lab demonstrates how an MLP can be used for time-series forecasting after converting sequential data into supervised-learning windows. Fine-tuning from checkpoints helps continue training and compare model performance.
